# %%
import base64

# Read SVG file and encode to base64
# with open('./Grover_rotation.svg', 'rb') as svg_file:
#     svg_base64 = base64.b64encode(svg_file.read()).decode('utf-8')

# Read PNG file and encode to base64
with open('./shor_alg.png', 'rb') as png_file:
    png_base64 = base64.b64encode(png_file.read()).decode('utf-8')

# Create markdown code
# markdown_code = f'![svg image](data:image/svg+xml;base64,{svg_base64})'
# markdown_code = f'<img src="data:image/svg+xml;base64,{svg_base64}" alt="svg image" width="50%"/>'
markdown_code = f'<img src="data:image/png;base64,{png_base64}" alt="description" width="70%"/>'


# print("Copy this markdown code:")
print(markdown_code)
# Out:
# <img src="data:image/png;base64,..." alt="description" width="70%"/>
