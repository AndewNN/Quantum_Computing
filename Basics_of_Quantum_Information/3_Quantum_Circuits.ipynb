# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.primitives import Sampler
from qiskit.visualization import plot_histogram

# %%
circuit = QuantumCircuit(1)

circuit.h(0)
circuit.s(0)
circuit.h(0)
circuit.t(0)

display(circuit.draw('mpl'))

# %%
X = QuantumRegister(1, 'X')
circuit = QuantumCircuit(X)

circuit.h(0)
circuit.s(0)
circuit.h(0)
circuit.t(0)

display(circuit.draw('mpl'))

# %%
X = QuantumRegister(1, 'X')
Y = QuantumRegister(1, 'Y')
A = ClassicalRegister(1, 'A')
B = ClassicalRegister(1, 'B')

circuit = QuantumCircuit(Y, X, B, A)
circuit.h(Y)
circuit.cx(Y, X)
circuit.measure(X, A)
circuit.measure(Y, B)

display(circuit.draw('mpl'))

# %%
result = Sampler().run(circuit).result()
stat = result.quasi_dists[0].binary_probabilities()
display(plot_histogram(stat))
# Out:
# /tmp/ipykernel_15953/465182504.py:1: DeprecationWarning: The class ``qiskit.primitives.sampler.Sampler`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseSamplerV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Sampler` class is `StatevectorSampler`.
#   result = Sampler().run(circuit).result()
